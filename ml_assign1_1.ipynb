# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
x = np.arange(0, 10, 0.1)  # x-values
y1 = np.sin(x)  # First set of data (sine wave)
y2 = np.cos(x)  # Second set of data (cosine wave)

# Create a figure and two axes
fig, ax1 = plt.subplots()

# Set the title
plt.title("Dual Lines Chart")

# Set the labels for the two y-axes
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y1-axis", color="tab:blue")
ax1.plot(x, y1, color="tab:blue", label="Y1 Data")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# Create a second y-axis
ax2 = ax1.twinx()
ax2.set_ylabel("Y2-axis", color="tab:red")
ax2.plot(x, y2, color="tab:red", label="Y2 Data")
ax2.tick_params(axis="y", labelcolor="tab:red")

# Add a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc="upper right")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
products = ["Product A", "Product B", "Product C", "Product D", "Product E"]
sales_product1 = [150, 200, 120, 250, 180]
sales_product2 = [100, 220, 140, 210, 160]

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Bar Chart")

# Define the bar width (optional)
bar_width = 0.35

# Set the positions of the bars
x = range(len(products))

# Plot the bars for Product 1
ax.bar(x, sales_product1, width=bar_width, label="Product 1")

# Plot the bars for Product 2, slightly shifted for comparison
ax.bar([i + bar_width for i in x], sales_product2, width=bar_width, label="Product 2")

# Set the x-axis labels
ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(products)

# Set the labels for the axes
ax.set_xlabel("Products")
ax.set_ylabel("Sales")

# Add a legend
ax.legend()

# Display the bar chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ["Category A", "Category B", "Category C", "Category D", "Category E"]
product1_sales = [150, 200, 120, 250, 180]
product2_sales = [100, 220, 140, 210, 160]
product3_sales = [180, 160, 190, 230, 140]

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Side-by-Side Bar Chart")

# Define the bar width (optional)
bar_width = 0.2

# Set the positions for the bars
x = np.arange(len(categories))

# Plot the bars for Product 1
ax.bar(x - bar_width, product1_sales, width=bar_width, label="Product 1")

# Plot the bars for Product 2
ax.bar(x, product2_sales, width=bar_width, label="Product 2")

# Plot the bars for Product 3
ax.bar(x + bar_width, product3_sales, width=bar_width, label="Product 3")

# Set the x-axis labels
ax.set_xticks(x)
ax.set_xticklabels(categories)

# Set the labels for the axes
ax.set_xlabel("Categories")
ax.set_ylabel("Sales")

# Add a legend
ax.legend()

# Display the side-by-side bar chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ["Category A", "Category B", "Category C", "Category D", "Category E"]
product1_subcategories = [30, 40, 10, 60, 20]
product2_subcategories = [20, 50, 30, 10, 30]
product3_subcategories = [10, 20, 30, 40, 10]

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Stacked Bar Chart")

# Set the positions for the bars
x = range(len(categories))

# Plot the bars for Product 1
ax.bar(x, product1_subcategories, label="Product 1")

# Plot the bars for Product 2 on top of Product 1
ax.bar(x, product2_subcategories, bottom=product1_subcategories, label="Product 2")

# Plot the bars for Product 3 on top of Product 1 and Product 2
ax.bar(x, product3_subcategories, bottom=[product1 + product2 for product1, product2 in zip(product1_subcategories, product2_subcategories)], label="Product 3")

# Set the x-axis labels
ax.set_xticks(x)
ax.set_xticklabels(categories)

# Set the labels for the axes
ax.set_xlabel("Categories")
ax.set_ylabel("Sales")

# Add a legend
ax.legend()

# Display the stacked bar chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data (random values from a normal distribution)
data = np.random.normal(0, 1, 1000)  # Mean = 0, Standard Deviation = 1, 1000 data points

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Histogram")

# Create the histogram
n, bins, patches = ax.hist(data, bins=20, color='blue', alpha=0.7, edgecolor='black')

# Set the x and y-axis labels
ax.set_xlabel("Value")
ax.set_ylabel("Frequency")

# Display the histogram
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data (random values from a normal distribution)
data = np.random.normal(0, 1, 1000)  # Mean = 0, Standard Deviation = 1, 1000 data points

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Cumulative Histogram")

# Create the cumulative histogram
n, bins, patches = ax.hist(data, bins=20, cumulative=True, color='blue', alpha=0.7, edgecolor='black', density=True)

# Set the x and y-axis labels
ax.set_xlabel("Value")
ax.set_ylabel("Cumulative Frequency")

# Display the cumulative histogram
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data (random values for two continuous variables)
x = np.random.normal(0, 1, 100)  # Sample data for the x-axis
y = 2 * x + np.random.normal(0, 1, 100)  # Sample data for the y-axis with a linear relationship to x

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Scatter Plot")

# Create the scatter plot
ax.scatter(x, y, color='blue', alpha=0.7, label='Data Points')

# Set the x and y-axis labels
ax.set_xlabel("X")
ax.set_ylabel("Y")

# Add a legend
ax.legend()

# Display the scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data (random values for three continuous variables)
x = np.random.normal(0, 1, 100)  # Sample data for the x-axis
y = np.random.normal(0, 1, 100)  # Sample data for the y-axis
z = np.random.uniform(10, 50, 100)  # Sample data for the size of bubbles

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Bubble Chart")

# Create the bubble chart
sc = ax.scatter(x, y, c=z, cmap="viridis", s=z, alpha=0.7, label='Data Points')

# Set the x and y-axis labels
ax.set_xlabel("X")
ax.set_ylabel("Y")

# Create a colorbar for the bubble sizes
cbar = plt.colorbar(sc)
cbar.set_label("Bubble Size")

# Add a legend
ax.legend()

# Display the bubble chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
sizes = [15, 30, 10, 25, 20]  # Sizes or proportions of each category
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen']
explode = (0.1, 0, 0, 0, 0)  # Explode a slice if needed

# Create a figure and axis
fig, ax = plt.subplots()

# Set the title
plt.title("Pie Chart")

# Create the pie chart
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

# Equal aspect ratio ensures that the pie is drawn as a circle.
ax.axis('equal')

# Display the pie chart
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data as a dictionary
data = {
    'CategoryA': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes'],
    'CategoryB': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create a crosstab
crosstab = pd.crosstab(df['CategoryA'], df['CategoryB'])

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, fmt='d', cmap='YlGnBu', cbar=True)

# Set labels for the axes
plt.xlabel("CategoryB")
plt.ylabel("CategoryA")

# Show the plot
plt.title("Crosstab Heatmap")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data as a dictionary
data = {
    'CategoryA': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes'],
    'CategoryB': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create a crosstab with column totals
crosstab = pd.crosstab(df['CategoryA'], df['CategoryB'], margins=True, margins_name='Total')

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, fmt='d', cmap='YlGnBu', cbar=True)

# Set labels for the axes
plt.xlabel("CategoryB")
plt.ylabel("CategoryA")

# Show the plot
plt.title("Crosstab Heatmap with Column Totals")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (list of numerical values)
data = [30, 45, 50, 60, 65, 75, 80, 85, 90, 95, 100]

# Create a box plot using seaborn
plt.figure(figsize=(6, 4))
sns.boxplot(data=data, color='skyblue', width=0.3)

# Set the title
plt.title("Box Plot")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define data for the bullet graph
categories = ['Revenue', 'Expenses', 'Profit']
actual = [500, 400, 100]
target = [600, 450, 200]
ranges = [(300, 600), (350, 500), (0, 300)]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 4))

# Create the bullet graph bars
for i, cat in enumerate(categories):
    ax.barh(cat, actual[i], color='green', label='Actual', height=0.5)
    ax.barh(cat, target[i] - actual[i], left=actual[i], color='gray', label='Target', height=0.5)

# Add reference lines
for i, cat in enumerate(categories):
    ax.axvline(ranges[i][0], color='red', linestyle='--', linewidth=1)
    ax.axvline(ranges[i][1], color='blue', linestyle='--', linewidth=1)

# Set the x-axis limits
ax.set_xlim(0, max(ranges, key=lambda x: x[1])[1])

# Add a legend
ax.legend(loc='upper right')

# Set the title
plt.title("Bullet Graph")

# Display the bullet graph
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 100)
y = np.cumsum(np.random.randn(100))  # Generate a cumulative random data series

# Create an area chart
plt.figure(figsize=(8, 4))
plt.fill_between(x, y, alpha=0.5, color='skyblue', label='Area Chart')

# Set labels for the axes
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Set the title
plt.title("Area Chart")

# Add a legend
plt.legend()

# Display the area chart
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (a 2D list representing values in a grid)
data = [
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
]

# Create a heatmap using seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(data, annot=True, fmt='d', cmap='YlGnBu', cbar=True)

# Set labels for the axes
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Set the title
plt.title("Heatmap")

# Show the plot
plt.show()

# %%
import folium

# Create a map centered on a specific location (e.g., New York City)
m = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Add a marker to the map
folium.Marker([40.7128, -74.0060], tooltip='New York City').add_to(m)

# Display the map
m.save('basic_map.html')

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Load a world map shapefile (you can download one online or use your own)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Sample data: Cities and their population
data = [
    {'City': 'New York', 'Population': 8398748, 'geometry': Point(-74.006, 40.7128)},
    {'City': 'Los Angeles', 'Population': 3990456, 'geometry': Point(-118.2437, 34.0522)},
    {'City': 'Chicago', 'Population': 2705994, 'geometry': Point(-87.6298, 41.8781)},
]

# Create a GeoDataFrame from the sample data
gdf = gpd.GeoDataFrame(data, crs='EPSG:4326')

# Plot the world map
world.plot()

# Plot the cities on the map and color them by population
gdf.plot(column='Population', markersize=gdf['Population'] / 50000, cmap='YlOrRd', legend=True, ax=plt.gca())

# Set the title
plt.title("Geographical Plot of Cities by Population")

# Show the plot
plt.show()
# Out:
# <ipython-input-23-5ff582404738>:6: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [15, 30, 10, 25, 20]

# Create a figure and axis
fig, ax = plt.subplots()

# Create the lollipop chart (dot plot)
ax.vlines(categories, ymin=0, ymax=values, color='skyblue', linewidth=3)
ax.plot(categories, values, 'o', color='blue', markersize=8, label='Data Points')

# Set the title
plt.title("Lollipop Chart")

# Set the x and y-axis labels
ax.set_xlabel("Categories")
ax.set_ylabel("Values")

# Add a legend
ax.legend()

# Display the lollipop chart
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for circular view chart
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [15, 30, 10, 25, 20]

# Create a figure and axis
fig, ax = plt.subplots()

# Create a pie chart to represent circular views
ax.pie(values, labels=categories, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightpink'])

# Set the title
plt.title("Circular View Chart")

# Display the circular view chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values1 = [15, 30, 10, 25, 20]
values2 = [10, 20, 5, 15, 25]

# Create a figure and axis
fig, ax = plt.subplots()

# Create a bar chart for the first data set
ax.bar(categories, values1, color='skyblue', label='Data Set 1')

# Create a line chart for the second data set
ax.plot(categories, values2, marker='o', color='lightcoral', label='Data Set 2')

# Set the title
plt.title("Dual Combination Chart")

# Set the x and y-axis labels
ax.set_xlabel("Categories")
ax.set_ylabel("Values")

# Add a legend
ax.legend()

# Display the dual combination chart
plt.xticks(rotation=45)
plt.show()

# %%
import plotly.express as px

# Sample hierarchical data
data = {
    'Category': ['Root', 'A', 'A', 'A', 'B', 'B'],
    'Subcategory': ['A1', 'A1', 'A2', 'A3', 'B1', 'B2'],
    'Value': [30, 10, 15, 5, 20, 10]
}

# Create a DataFrame
import pandas as pd
df = pd.DataFrame(data)

# Create a treemap using plotly express
fig = px.treemap(df, path=['Category', 'Subcategory'], values='Value')

# Set the title
fig.update_layout(title_text="Treemap")

# Show the treemap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Sample data for a funnel chart
stages = ['Stage 1', 'Stage 2', 'Stage 3', 'Stage 4', 'Stage 5']
values = [100, 80, 60, 40, 20]

# Create a DataFrame
import pandas as pd
df = pd.DataFrame({'Stages': stages, 'Values': values})

# Create a funnel chart using plotly express
fig = px.funnel(df, x='Values', y='Stages')

# Set the title
fig.update_layout(title_text="Funnel Chart")

# Show the funnel chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# Sample data for the funnel chart
stages = ['Stage 1', 'Stage 2', 'Stage 3', 'Stage 4', 'Stage 5']
values = [100, 80, 60, 40, 20]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Create rectangles to represent the funnel stages
for i, stage in enumerate(stages):
    ax.bar(i, values[i], color='skyblue', label=stage)

# Set the x-axis labels
ax.set_xticks(range(len(stages)))
ax.set_xticklabels(stages)

# Set the title
plt.title("Traditional Funnel Chart")

# Set the y-axis label
ax.set_ylabel("Values")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for the waterfall chart
categories = ['Starting', 'Category A', 'Category B', 'Category C', 'Category D', 'Ending']
values = [100, 30, -15, 40, -10, 145]

# Create a figure and axis
fig, ax = plt.subplots()

# Initialize the cumulative total
cumulative_total = 0

# Create the waterfall chart
for i, category in enumerate(categories):
    if values[i] >= 0:
        ax.bar(category, values[i], bottom=cumulative_total, color='lightgreen')
    else:
        ax.bar(category, values[i], bottom=cumulative_total, color='lightcoral')
    cumulative_total += values[i]

# Set the title
plt.title("Waterfall Chart")

# Set the x-axis and y-axis labels
ax.set_xlabel("Categories")
ax.set_ylabel("Values")

# Show the plot
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data for the Gantt chart
tasks = ['Task 1', 'Task 2', 'Task 3', 'Task 4']
start_dates = ['2023-10-01', '2023-10-10', '2023-10-15', '2023-10-20']
end_dates = ['2023-10-05', '2023-10-15', '2023-10-18', '2023-10-25']

# Create a DataFrame from the sample data
df = pd.DataFrame({'Task': tasks, 'Start': pd.to_datetime(start_dates), 'End': pd.to_datetime(end_dates)})

# Create a Gantt chart
fig, ax = plt.subplots(figsize=(8, 4))

for i, task in enumerate(df['Task']):
    ax.barh(task, left=df['Start'][i], width=df['End'][i] - df['Start'][i], label=task)

# Set the title
plt.title("Gantt Chart")

# Set the x and y-axis labels
ax.set_xlabel("Timeline")
ax.set_ylabel("Tasks")

# Show the Gantt chart
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
# Step 1: Generate a dataset with noise
import numpy as np
import matplotlib.pyplot as plt

# Generate random data with some noise
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# Step 2: Plot the data
plt.scatter(X, y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Scatter Plot of Data")
plt.show()

# Step 3: Estimate initial parametric values
# Initialize parameters (slope and intercept)
theta0 = np.random.rand()
theta1 = np.random.rand()

# Step 4: Plot the error (cost) curve
# Define the cost function (mean squared error)
# Step 4: Plot the error (cost) curve
# Define the cost function (mean squared error)



# Step 5: Implement gradient descent
# Define the learning rate and the number of iterations
learning_rate_small = 0.01
learning_rate_large = 0.1
num_iterations = 1000

# Initialize parameters
theta0_small, theta1_small = np.random.rand(), np.random.rand()
theta0_large, theta1_large = np.random.rand(), np.random.rand()

# Create lists to store the cost values at each step
cost_history_small = []
cost_history_large = []

# Gradient Descent
for _ in range(num_iterations):
    # Calculate the gradients
    gradients_small = (1 / len(y)) * X.T.dot(X.dot(theta1_small) + theta0_small - y)
    gradients_large = (1 / len(y)) * X.T.dot(X.dot(theta1_large) + theta0_large - y)

    # Update the parameters
    theta0_small -= learning_rate_small * gradients_small[0]
    theta1_small -= learning_rate_small * gradients_small[1]

    theta0_large -= learning_rate_large * gradients_large[0]
    theta1_large -= learning_rate_large * gradients_large[1]

    # Calculate and store the cost at each step
    cost_history_small.append(compute_cost(theta0_small, theta1_small, X, y))
    cost_history_large.append(compute_cost(theta0_large, theta1_large, X, y))

# Step 6: Output the results in tabular form
import pandas as pd

iterations = np.arange(1, num_iterations + 1)
results_small = pd.DataFrame({'Iteration': iterations, 'Theta0': theta0_small, 'Theta1': theta1_small, 'Cost': cost_history_small})
results_large = pd.DataFrame({'Iteration': iterations, 'Theta0': theta0_large, 'Theta1': theta1_large, 'Cost': cost_history_large})

print("Gradient Descent with Small Learning Rate")
print(results_small.head(10))
print("\nGradient Descent with Large Learning Rate")
print(results_large.head(10))

# Step 7: Plot the final curve
plt.scatter(X, y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Linear Regression Fit")

# Plot the regression line with small learning rate
plt.plot(X, X * theta1_small + theta0_small, color='red', label=f'Small LR: y = {theta1_small:.2f}x + {theta0_small:.2f}')

# Plot the regression line with large learning rate
plt.plot(X, X * theta1_large + theta0_large, color='green', label=f'Large LR: y = {theta1_large:.2f}x + {theta0_large:.2f}')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-9a7bad22b735> in <cell line: 44>()
#      49     # Update the parameters
#      50     theta0_small -= learning_rate_small * gradients_small[0]
# ---> 51     theta1_small -= learning_rate_small * gradients_small[1]
#      52
#      53     theta0_large -= learning_rate_large * gradients_large[0]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate a dataset with noise
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# Step 2: Plot the data
plt.scatter(X, y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Scatter Plot of Data")
plt.show()

# Step 3: Estimate initial parametric values
theta0 = np.random.rand()
theta1 = np.random.rand()

# Step 4: Plot the error (cost) curve
def compute_cost(theta0, theta1, X, y):
    m = len(y)
    predictions = X.dot(theta1) + theta0
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))
    return cost

# Create a range of theta0 and theta1 values
theta0_vals = np.linspace(-2, 6, 100)
theta1_vals = np.linspace(-2, 6, 100)
cost_vals = np.zeros((len(theta0_vals), len(theta1_vals))

for i in range(len(theta0_vals)):
    for j in range(len(theta1_vals)):
        cost_vals[i, j] = compute_cost(theta0_vals[i], theta1_vals[j], X, y)

# Plot the cost curve
plt.contourf(theta0_vals, theta1_vals, cost_vals, levels=20, cmap='viridis')
plt.colorbar()
plt.xlabel('Theta0')
plt.ylabel('Theta1')
plt.title("Cost Curve")

# Step 5: Use gradient descent
learning_rate_small = 0.01
learning_rate_large = 0.1
num_iterations = 1000

# Initialize parameters
theta0_small, theta1_small = np.random.rand(), np.random.rand()
theta0_large, theta1_large = np.random.rand(), np.random.rand()

# Create lists to store the cost values at each step
cost_history_small = []
cost_history_large = []

for _ in range(num_iterations):
    # Calculate the gradients
    gradients_small = (1 / len(y)) * X.T.dot(X.dot(theta1_small) + theta0_small - y)
    gradients_large = (1 / len(y)) * X.T.dot(X.dot(theta1_large) + theta0_large - y)

    # Update the parameters
    theta0_small -= learning_rate_small * gradients_small[0]
    theta1_small -= learning_rate_small * gradients_small[1]

    theta0_large -= learning_rate_large * gradients_large[0]
    theta1_large -= learning_rate_large * gradients_large[1]

    # Calculate and store the cost at each step
    cost_history_small.append(compute_cost(theta0_small, theta1_small, X, y))
    cost_history_large.append(compute_cost(theta0_large, theta1_large, X, y)

# Step 6: Output the results in tabular form
import pandas as pd

iterations = np.arange(1, num_iterations + 1)
results_small = pd.DataFrame({'Iteration': iterations, 'Theta0': theta0_small, 'Theta1': theta1_small, 'Cost': cost_history_small})
results_large = pd.DataFrame({'Iteration': iterations, 'Theta0': theta0_large, 'Theta1': theta1_large, 'Cost': cost_history_large})

print("Gradient Descent with Small Learning Rate")
print(results_small.head(10))
print("\nGradient Descent with Large Learning Rate")
print(results_large.head(10))

# Step 7: Plot the final curve
plt.scatter(X, y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Linear Regression Fit")

plt.plot(X, X * theta1_small + theta0_small, color='red', label=f'Small LR: y = {theta1_small:.2f}x + {theta0_small:.2f}')
plt.plot(X, X * theta1_large + theta0_large, color='green', label=f'Large LR: y = {theta1_large:.2f}x + {theta0_large:.2f}')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-35-87ce5fbd788e>, line 32)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate a dataset with noise
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# Step 2: Plot the data
plt.scatter(X, y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Scatter Plot of Data")
plt.show()

# Step 3: Estimate initial parametric values
theta0 = np.random.rand()
theta1 = np.random.rand()

# Step 4: Plot the error (cost) curve
def compute_cost(theta0, theta1, X, y):
    m = len(y)
    predictions = X.dot(theta1) + theta0
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))
    return cost

# Create a range of theta0 and theta1 values
theta0_vals = np.linspace(-2, 6, 100)
theta1_vals = np.linspace(-2, 6, 100)
cost_vals = np.zeros((len(theta0_vals), len(theta1_vals))

for i in range(len(theta0_vals)):
    for j in range(len(theta1_vals)):
        cost_vals[i, j] = compute_cost(theta0_vals[i], theta1_vals[j], X, y)

# Plot the cost curve
plt.contourf(theta0_vals, theta1_vals, cost_vals, levels=20, cmap='viridis')
plt.colorbar()
plt.xlabel('Theta0')
plt.ylabel('Theta1')
plt.title("Cost Curve")

# Step 5: Use gradient descent
learning_rate_small = 0.01
learning_rate_large = 0.1
num_iterations = 1000

# Initialize parameters
theta0_small, theta1_small = np.random.rand(), np.random.rand()
theta0_large, theta1_large = np.random.rand(), np.random.rand()

# Create lists to store the cost values at each step
cost_history_small = []
cost_history_large = []

for _ in range(num_iterations):
    # Calculate the gradients
    gradients_small = (1 / len(y)) * X.T.dot(X.dot(theta1_small) + theta0_small - y)
    gradients_large = (1 / len(y)) * X.T.dot(X.dot(theta1_large) + theta0_large - y)

    # Update the parameters
    theta0_small -= learning_rate_small * gradients_small[0]
    theta1_small -= learning_rate_small * gradients_small[1]

    theta0_large -= learning_rate_large * gradients_large[0]
    theta1_large -= learning_rate_large * gradients_large[1]

    # Calculate and store the cost at each step
    cost_history_small.append(compute_cost(theta0_small, theta1_small, X, y))
    cost_history_large.append(compute_cost(theta0_large, theta1_large, X, y)

# Step 6: Output the results in tabular form
import pandas as pd

iterations = np.arange(1, num_iterations + 1)
results_small = pd.DataFrame({'Iteration': iterations, 'Theta0': theta0_small, 'Theta1': theta1_small, 'Cost': cost_history_small})
results_large = pd.DataFrame({'Iteration': iterations, 'Theta0': theta0_large, 'Theta1': theta1_large, 'Cost': cost_history_large})

print("Gradient Descent with Small Learning Rate")
print(results_small.head(10))
print("\nGradient Descent with Large Learning Rate")
print(results_large.head(10))

# Step 7: Plot the final curve
plt.scatter(X, y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Linear Regression Fit")

plt.plot(X, X * theta1_small + theta0_small, color='red', label=f'Small LR: y = {theta1_small:.2f}x + {theta0_small:.2f}')
plt.plot(X, X * theta1_large + theta0_large, color='green', label=f'Large LR: y = {theta1_large:.2f}x + {theta0_large:.2f}')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-36-87ce5fbd788e>, line 32)
